# %% [markdown]
# #**MACHINE LEARNING PROJECT**
# **TITLE**:
# Using Customer Retail Dataset Implement Various Models and Compare Them.

# %% [markdown]
# ###IMPORT LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ###LOAD DATASET

# %%
df=pd.read_excel("customer_reatil.csv.xlsx")

# %% [markdown]
# ###DATASET PREVIEW

# %%
print(df.head())

# %% [markdown]
# ###DATA PREPROCESSING

# %%
df=df.dropna()

# %%
df=df[['Quantity','UnitPrice','Country']]

# %% [markdown]
# ###ENCODING CATEGORICAL DATA

# %%
encoder=LabelEncoder()
df['Country_encoded']=encoder.fit_transform(df['Country'])

# %% [markdown]
# ###DATA VISUALIZATION

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['Quantity'],df['UnitPrice'])
plt.xlabel('Quantity')
plt.ylabel('UnitPrice')
plt.title('Scatter Plot of Quantity vs UnitPrice')
plt.show()

# %% [markdown]
# ###TRAIN_TEST SPLIT

# %%
x=df[['Quantity','UnitPrice']]
y=df['Country_encoded']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ###LOGISTIC REGRESSION MODEL

# %%
print("Logistic Regression")
log_model=LogisticRegression(max_iter=1000)
log_model.fit(x_train,y_train)
log_pred=log_model.predict(x_test)
log_accuracy=accuracy_score(y_test,log_pred)
print("Accuracy:",log_accuracy)
cm=confusion_matrix(y_test,log_pred)
print("Confusion Matrix:")
print(cm)

# %% [markdown]
# ###DECISION TREE CLASSIFIER

# %%
print("Decision Tree")
dt_model=DecisionTreeClassifier()
dt_model.fit(x_train,y_train)
dt_pred=dt_model.predict(x_test)
dt_accuracy=accuracy_score(y_test,dt_pred)
print("Accuracy:",dt_accuracy)
cm=confusion_matrix(y_test,dt_pred)
print("Confusion Matrix:")
print(cm)

# %% [markdown]
# ###K-NEAREST NEIGHBORS (KNN)

# %%
print("KNN")
knn_model=KNeighborsClassifier()
knn_model.fit(x_train,y_train)
knn_pred=knn_model.predict(x_test)
knn_accuracy=accuracy_score(y_test,knn_pred)
print("Accuracy:",knn_accuracy)
cm=confusion_matrix(y_test,knn_pred)
print("Confusion Matrix:")
print(cm)

# %% [markdown]
# ###MODEL EVALUATION

# %%
models=[
    'Logistic Regression',
    'Decision Tree',
    'KNN'
]
accuracies=[
    log_accuracy,
    dt_accuracy,
    knn_accuracy
]

# %% [markdown]
# ###MODEL COMPARISION

# %%
plt.figure(figsize=(8,5))
plt.bar(models,accuracies)
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Model Accuracy Comparison')
plt.show()

# %% [markdown]
# ###**CONCLUSION**
#
# This project compared the performance of three Machine Learning algorithms: Logistic Regression, Decision Tree Classifier, and K-Nearest Neighbors (KNN) using customer retail data.
#
# The models were trained and evaluated using accuracy scores and confusion matrices.
#
# Based on the evaluation results, the Decision Tree Classifier achieved the highest accuracy among all the models and performed better on this dataset.
